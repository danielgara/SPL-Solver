# %% [markdown]
# # Referencias
#
# ```javascript
# @article{ benavides_2013,
#   author  = {
#     David Benavides,
#     Alexander Felfernig,
#     José A. Galindo
#     and Florian Reinfrank
#   },
#   title   = { Automated Analysis in Feature Modelling and Product Configuration },
#   year    = 2013,
# }
#
# @article{ northrop_2002,
#   author  = { Linda M. Northrop },
#   title   = { SEI’s Software Product Line Tenets },
#   journal = { IEEE Software },
#   pages   = { 32-40 },
#   year    = 2002,
# }
#
# @article{ bachmann_2002,
#   author  = {
#     Felix Bachmann
#     Paul C. Clements
#   },
#   title   = { Variability in Software Product Lines },
#   year    = 2005,
# }
#
# @article{ mendonca_2002,
#   author  = {
#     Marcilio Mendonca
#     Andrzej W ˛asowski
#     Krzysztof Czarnecki
#   },
#   title   = { SAT-based Analysis of Feature Models is Easy },
#   year    = 2009,
# }
#
# @article{ mkrttchian_2016,
#   author  = {
#     Vardan Mkrttchian
#     Alexander Bershadsky
#     Alexander Bozhday
#     Mikhail Kataev
#     Sergey Kataev
#   },
#   title   = { Development of the System for Authoring Three-Dimensional Learning Applications for Use in E-Learning Environment },
#   year    = 2016,
# }
#
# @article{ evseeva_2012,
#   author  = {
#     Julia Igorevna Evseeva
#     Alexander Bozhday
#     Alexei Anatolievich
#   },
#   title   = { Experience with Automatic Product Derivation of Mobile Applications Using Model-Driven Techniques },
#   year    = 2012,
# }
#
# @article{ white_2010,
#   author  = {
#     Jules White
#     David Benavides
#     Douglas C. Schmidt
#     Pablo Trinidad
#     Brian Dougherty
#     Antonio Ruiz-Cortés
#   },
#   title   = { Automated diagnosis of feature model configurations },
#   year    = 2010,
# }
#
# @mastersthesis{ leumann_2017,
#   author       = { Oliver Leumann },
#   title        = { Microservices-Based Feature Models },
#   school       = { University of Zurich },
#   year         = 2017,
# }
#
# ```
#
#
# <!-- https://verbosus.com/bibtex-style-examples.html -->
